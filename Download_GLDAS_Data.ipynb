# %%
import requests
counter = 1
with open('url.txt') as my_file:
    for line in my_file:
        URL = line.strip()
        FILENAME = str(counter) + '.nc4'
        counter+= 1
        result = requests.get(URL)
        try:
            result.raise_for_status()
            f = open(FILENAME,'wb')
            f.write(result.content)
            f.close()
            print('contents of URL written to '+FILENAME)
        except:
            print('requests.get() returned an error code '+str(result.status_code))
# Out:
# contents of URL written to 1.nc4
# contents of URL written to 2.nc4
# contents of URL written to 3.nc4
# contents of URL written to 4.nc4
# contents of URL written to 5.nc4
# contents of URL written to 6.nc4
# contents of URL written to 7.nc4
# contents of URL written to 8.nc4
# contents of URL written to 9.nc4
# contents of URL written to 10.nc4
# contents of URL written to 11.nc4
# contents of URL written to 12.nc4
# contents of URL written to 13.nc4
# contents of URL written to 14.nc4
# contents of URL written to 15.nc4
# contents of URL written to 16.nc4
# contents of URL written to 17.nc4
# contents of URL written to 18.nc4
# contents of URL written to 19.nc4
# contents of URL written to 20.nc4
# contents of URL written to 21.nc4
# contents of URL written to 22.nc4
# contents of URL written to 23.nc4
# contents of URL written to 24.nc4
# contents of URL written to 25.nc4
# contents of URL written to 26.nc4
# contents of URL written to 27.nc4
# contents of URL written to 28.nc4
# contents of URL written to 29.nc4
# contents of URL written to 30.nc4
# contents of URL written to 31.nc4
# contents of URL written to 32.nc4
# contents of URL written to 33.nc4
# contents of URL written to 34.nc4
# contents of URL written to 35.nc4
# contents of URL written to 36.nc4
# contents of URL written to 37.nc4
# contents of URL written to 38.nc4
# contents of URL written to 39.nc4
# contents of URL written to 40.nc4
# contents of URL written to 41.nc4
# contents of URL written to 42.nc4
# contents of URL written to 43.nc4
# contents of URL written to 44.nc4
# contents of URL written to 45.nc4
# contents of URL written to 46.nc4
# contents of URL written to 47.nc4
# contents of URL written to 48.nc4
# contents of URL written to 49.nc4
# contents of URL written to 50.nc4
# contents of URL written to 51.nc4
# contents of URL written to 52.nc4
# contents of URL written to 53.nc4
# contents of URL written to 54.nc4
# contents of URL written to 55.nc4
# contents of URL written to 56.nc4
# contents of URL written to 57.nc4
# contents of URL written to 58.nc4
# contents of URL written to 59.nc4
# contents of URL written to 60.nc4
# contents of URL written to 61.nc4
# contents of URL written to 62.nc4
# contents of URL written to 63.nc4
# contents of URL written to 64.nc4
# contents of URL written to 65.nc4
# contents of URL written to 66.nc4
# contents of URL written to 67.nc4
# contents of URL written to 68.nc4
# contents of URL written to 69.nc4
# contents of URL written to 70.nc4
# contents of URL written to 71.nc4
# contents of URL written to 72.nc4
# contents of URL written to 73.nc4
# contents of URL written to 74.nc4
# contents of URL written to 75.nc4
# contents of URL written to 76.nc4
# contents of URL written to 77.nc4
# contents of URL written to 78.nc4
# contents of URL written to 79.nc4
# contents of URL written to 80.nc4
# contents of URL written to 81.nc4
# contents of URL written to 82.nc4
# contents of URL written to 83.nc4
# contents of URL written to 84.nc4
# contents of URL written to 85.nc4
# contents of URL written to 86.nc4
# contents of URL written to 87.nc4
# contents of URL written to 88.nc4
# contents of URL written to 89.nc4
# contents of URL written to 90.nc4
# contents of URL written to 91.nc4
# contents of URL written to 92.nc4
# contents of URL written to 93.nc4
# contents of URL written to 94.nc4
# contents of URL written to 95.nc4
# contents of URL written to 96.nc4
# contents of URL written to 97.nc4
# contents of URL written to 98.nc4
# contents of URL written to 99.nc4
# contents of URL written to 100.nc4
# contents of URL written to 101.nc4
# contents of URL written to 102.nc4
# contents of URL written to 103.nc4
# contents of URL written to 104.nc4
# contents of URL written to 105.nc4
# contents of URL written to 106.nc4
# contents of URL written to 107.nc4
# contents of URL written to 108.nc4
# contents of URL written to 109.nc4
# contents of URL written to 110.nc4
# contents of URL written to 111.nc4
# contents of URL written to 112.nc4
# contents of URL written to 113.nc4
# contents of URL written to 114.nc4
# contents of URL written to 115.nc4
# contents of URL written to 116.nc4
# contents of URL written to 117.nc4
# contents of URL written to 118.nc4
# contents of URL written to 119.nc4
# contents of URL written to 120.nc4
# contents of URL written to 121.nc4
# contents of URL written to 122.nc4
# contents of URL written to 123.nc4
# contents of URL written to 124.nc4
# contents of URL written to 125.nc4
# contents of URL written to 126.nc4
# contents of URL written to 127.nc4
# contents of URL written to 128.nc4
# contents of URL written to 129.nc4
# contents of URL written to 130.nc4
# contents of URL written to 131.nc4
# contents of URL written to 132.nc4
# contents of URL written to 133.nc4
# contents of URL written to 134.nc4
# contents of URL written to 135.nc4
# contents of URL written to 136.nc4
# contents of URL written to 137.nc4
# contents of URL written to 138.nc4
# contents of URL written to 139.nc4
# contents of URL written to 140.nc4
# contents of URL written to 141.nc4
# contents of URL written to 142.nc4
# contents of URL written to 143.nc4
# contents of URL written to 144.nc4
# contents of URL written to 145.nc4
# contents of URL written to 146.nc4
# contents of URL written to 147.nc4
# contents of URL written to 148.nc4
# contents of URL written to 149.nc4
# contents of URL written to 150.nc4
# contents of URL written to 151.nc4
# contents of URL written to 152.nc4
# contents of URL written to 153.nc4
# contents of URL written to 154.nc4
# contents of URL written to 155.nc4
# contents of URL written to 156.nc4
# contents of URL written to 157.nc4
# contents of URL written to 158.nc4
# contents of URL written to 159.nc4
# contents of URL written to 160.nc4
# contents of URL written to 161.nc4
# contents of URL written to 162.nc4
# contents of URL written to 163.nc4
# contents of URL written to 164.nc4
# contents of URL written to 165.nc4
# contents of URL written to 166.nc4
# contents of URL written to 167.nc4
# contents of URL written to 168.nc4
# contents of URL written to 169.nc4
# contents of URL written to 170.nc4
# contents of URL written to 171.nc4
# contents of URL written to 172.nc4
# contents of URL written to 173.nc4
# contents of URL written to 174.nc4
# contents of URL written to 175.nc4
# contents of URL written to 176.nc4
# contents of URL written to 177.nc4
# contents of URL written to 178.nc4
# contents of URL written to 179.nc4
# contents of URL written to 180.nc4
# contents of URL written to 181.nc4
# contents of URL written to 182.nc4
# contents of URL written to 183.nc4
# contents of URL written to 184.nc4
# contents of URL written to 185.nc4
# contents of URL written to 186.nc4
# contents of URL written to 187.nc4
# contents of URL written to 188.nc4
# contents of URL written to 189.nc4
# contents of URL written to 190.nc4
# contents of URL written to 191.nc4
# contents of URL written to 192.nc4
# contents of URL written to 193.nc4
# contents of URL written to 194.nc4
# contents of URL written to 195.nc4
# contents of URL written to 196.nc4
# contents of URL written to 197.nc4
# contents of URL written to 198.nc4
# contents of URL written to 199.nc4
# contents of URL written to 200.nc4
# contents of URL written to 201.nc4
# contents of URL written to 202.nc4
# contents of URL written to 203.nc4
# contents of URL written to 204.nc4
# contents of URL written to 205.nc4
# contents of URL written to 206.nc4
# contents of URL written to 207.nc4
# contents of URL written to 208.nc4
# contents of URL written to 209.nc4
# contents of URL written to 210.nc4
# contents of URL written to 211.nc4
# contents of URL written to 212.nc4
# contents of URL written to 213.nc4
# contents of URL written to 214.nc4
# contents of URL written to 215.nc4
# contents of URL written to 216.nc4
# contents of URL written to 217.nc4
# contents of URL written to 218.nc4
# contents of URL written to 219.nc4
# contents of URL written to 220.nc4
# contents of URL written to 221.nc4
# contents of URL written to 222.nc4
# contents of URL written to 223.nc4
# contents of URL written to 224.nc4
# contents of URL written to 225.nc4
# contents of URL written to 226.nc4
# contents of URL written to 227.nc4
# contents of URL written to 228.nc4
# contents of URL written to 229.nc4
# contents of URL written to 230.nc4
# contents of URL written to 231.nc4
# contents of URL written to 232.nc4
# contents of URL written to 233.nc4
# contents of URL written to 234.nc4
# contents of URL written to 235.nc4
# contents of URL written to 236.nc4
# contents of URL written to 237.nc4
# contents of URL written to 238.nc4
# contents of URL written to 239.nc4
# contents of URL written to 240.nc4
# contents of URL written to 241.nc4
# contents of URL written to 242.nc4
# contents of URL written to 243.nc4
# contents of URL written to 244.nc4
# contents of URL written to 245.nc4
# contents of URL written to 246.nc4
# contents of URL written to 247.nc4
# contents of URL written to 248.nc4
# contents of URL written to 249.nc4
# contents of URL written to 250.nc4
# contents of URL written to 251.nc4
# contents of URL written to 252.nc4
# contents of URL written to 253.nc4
# contents of URL written to 254.nc4
# contents of URL written to 255.nc4
# contents of URL written to 256.nc4
# contents of URL written to 257.nc4
# contents of URL written to 258.nc4
# contents of URL written to 259.nc4
# contents of URL written to 260.nc4
# contents of URL written to 261.nc4
# contents of URL written to 262.nc4
# contents of URL written to 263.nc4
# contents of URL written to 264.nc4
# contents of URL written to 265.nc4
# contents of URL written to 266.nc4
# contents of URL written to 267.nc4
# contents of URL written to 268.nc4
# contents of URL written to 269.nc4
# contents of URL written to 270.nc4
# contents of URL written to 271.nc4
# contents of URL written to 272.nc4
# contents of URL written to 273.nc4
# contents of URL written to 274.nc4
# contents of URL written to 275.nc4
# contents of URL written to 276.nc4
# contents of URL written to 277.nc4
# contents of URL written to 278.nc4
# contents of URL written to 279.nc4
# contents of URL written to 280.nc4
# contents of URL written to 281.nc4
# contents of URL written to 282.nc4
# contents of URL written to 283.nc4
# contents of URL written to 284.nc4
# contents of URL written to 285.nc4
# contents of URL written to 286.nc4
# contents of URL written to 287.nc4
# contents of URL written to 288.nc4
# contents of URL written to 289.nc4
# contents of URL written to 290.nc4
# contents of URL written to 291.nc4
# contents of URL written to 292.nc4
# contents of URL written to 293.nc4
# contents of URL written to 294.nc4
# contents of URL written to 295.nc4
# contents of URL written to 296.nc4
# contents of URL written to 297.nc4
# contents of URL written to 298.nc4
# contents of URL written to 299.nc4
# contents of URL written to 300.nc4
# contents of URL written to 301.nc4
# contents of URL written to 302.nc4
# contents of URL written to 303.nc4
# contents of URL written to 304.nc4
# contents of URL written to 305.nc4
# contents of URL written to 306.nc4
# contents of URL written to 307.nc4
# contents of URL written to 308.nc4
# contents of URL written to 309.nc4
# contents of URL written to 310.nc4
# contents of URL written to 311.nc4
# contents of URL written to 312.nc4
# contents of URL written to 313.nc4
# contents of URL written to 314.nc4
# contents of URL written to 315.nc4
# contents of URL written to 316.nc4
# contents of URL written to 317.nc4
# contents of URL written to 318.nc4
# contents of URL written to 319.nc4
# contents of URL written to 320.nc4
# contents of URL written to 321.nc4
# contents of URL written to 322.nc4
# contents of URL written to 323.nc4
# contents of URL written to 324.nc4
# contents of URL written to 325.nc4
# contents of URL written to 326.nc4
# contents of URL written to 327.nc4
# contents of URL written to 328.nc4
# contents of URL written to 329.nc4
# contents of URL written to 330.nc4
# contents of URL written to 331.nc4
# contents of URL written to 332.nc4
# contents of URL written to 333.nc4
# contents of URL written to 334.nc4
# contents of URL written to 335.nc4
# contents of URL written to 336.nc4
# contents of URL written to 337.nc4
# contents of URL written to 338.nc4
# contents of URL written to 339.nc4
# contents of URL written to 340.nc4
# contents of URL written to 341.nc4
# contents of URL written to 342.nc4
# contents of URL written to 343.nc4
# contents of URL written to 344.nc4
# contents of URL written to 345.nc4
# contents of URL written to 346.nc4
# contents of URL written to 347.nc4
# contents of URL written to 348.nc4
# contents of URL written to 349.nc4
# contents of URL written to 350.nc4
# contents of URL written to 351.nc4
# contents of URL written to 352.nc4
# contents of URL written to 353.nc4
# contents of URL written to 354.nc4
# contents of URL written to 355.nc4
# contents of URL written to 356.nc4
# contents of URL written to 357.nc4
# contents of URL written to 358.nc4
# contents of URL written to 359.nc4
# contents of URL written to 360.nc4
# contents of URL written to 361.nc4
# contents of URL written to 362.nc4
# contents of URL written to 363.nc4
# contents of URL written to 364.nc4
# contents of URL written to 365.nc4
# contents of URL written to 366.nc4
# contents of URL written to 367.nc4
# contents of URL written to 368.nc4
# contents of URL written to 369.nc4
# contents of URL written to 370.nc4
# contents of URL written to 371.nc4
# contents of URL written to 372.nc4
# contents of URL written to 373.nc4
# contents of URL written to 374.nc4
# contents of URL written to 375.nc4
# contents of URL written to 376.nc4
# contents of URL written to 377.nc4
# contents of URL written to 378.nc4
# contents of URL written to 379.nc4
# contents of URL written to 380.nc4
# contents of URL written to 381.nc4
# contents of URL written to 382.nc4
# contents of URL written to 383.nc4
# contents of URL written to 384.nc4
# contents of URL written to 385.nc4
# contents of URL written to 386.nc4
# contents of URL written to 387.nc4
# contents of URL written to 388.nc4
# contents of URL written to 389.nc4
# contents of URL written to 390.nc4
# contents of URL written to 391.nc4
# contents of URL written to 392.nc4
# contents of URL written to 393.nc4
# contents of URL written to 394.nc4
# contents of URL written to 395.nc4
# contents of URL written to 396.nc4
# contents of URL written to 397.nc4
# contents of URL written to 398.nc4
# contents of URL written to 399.nc4
# contents of URL written to 400.nc4
# contents of URL written to 401.nc4
# contents of URL written to 402.nc4
# contents of URL written to 403.nc4
# contents of URL written to 404.nc4
# contents of URL written to 405.nc4
# contents of URL written to 406.nc4
# contents of URL written to 407.nc4
# contents of URL written to 408.nc4
# contents of URL written to 409.nc4
# contents of URL written to 410.nc4
# contents of URL written to 411.nc4
# contents of URL written to 412.nc4
# contents of URL written to 413.nc4
# contents of URL written to 414.nc4
# contents of URL written to 415.nc4
# contents of URL written to 416.nc4
# contents of URL written to 417.nc4
# contents of URL written to 418.nc4
# contents of URL written to 419.nc4
# contents of URL written to 420.nc4
# contents of URL written to 421.nc4
# contents of URL written to 422.nc4
# contents of URL written to 423.nc4
# contents of URL written to 424.nc4
# contents of URL written to 425.nc4
# contents of URL written to 426.nc4
# contents of URL written to 427.nc4
# contents of URL written to 428.nc4
# contents of URL written to 429.nc4
# contents of URL written to 430.nc4
# contents of URL written to 431.nc4
# contents of URL written to 432.nc4
# contents of URL written to 433.nc4
# contents of URL written to 434.nc4
# contents of URL written to 435.nc4
# contents of URL written to 436.nc4
# contents of URL written to 437.nc4
# contents of URL written to 438.nc4
# contents of URL written to 439.nc4
# contents of URL written to 440.nc4
# contents of URL written to 441.nc4
# contents of URL written to 442.nc4
# contents of URL written to 443.nc4
# contents of URL written to 444.nc4
# contents of URL written to 445.nc4
# contents of URL written to 446.nc4
# contents of URL written to 447.nc4
# contents of URL written to 448.nc4
# contents of URL written to 449.nc4
# contents of URL written to 450.nc4
# contents of URL written to 451.nc4
# contents of URL written to 452.nc4
# contents of URL written to 453.nc4
# contents of URL written to 454.nc4
# contents of URL written to 455.nc4
# contents of URL written to 456.nc4
# contents of URL written to 457.nc4
# contents of URL written to 458.nc4
# contents of URL written to 459.nc4
# contents of URL written to 460.nc4
# contents of URL written to 461.nc4
# contents of URL written to 462.nc4
# contents of URL written to 463.nc4
# contents of URL written to 464.nc4
# contents of URL written to 465.nc4
# contents of URL written to 466.nc4
# contents of URL written to 467.nc4
# contents of URL written to 468.nc4
# contents of URL written to 469.nc4
# contents of URL written to 470.nc4
# contents of URL written to 471.nc4
# contents of URL written to 472.nc4
# contents of URL written to 473.nc4
# contents of URL written to 474.nc4
# contents of URL written to 475.nc4
# contents of URL written to 476.nc4
# contents of URL written to 477.nc4
# contents of URL written to 478.nc4
# contents of URL written to 479.nc4
# contents of URL written to 480.nc4
# contents of URL written to 481.nc4
# contents of URL written to 482.nc4
# contents of URL written to 483.nc4
# contents of URL written to 484.nc4
# contents of URL written to 485.nc4
# contents of URL written to 486.nc4
# contents of URL written to 487.nc4
# contents of URL written to 488.nc4
# contents of URL written to 489.nc4
# contents of URL written to 490.nc4
# contents of URL written to 491.nc4
# contents of URL written to 492.nc4
# contents of URL written to 493.nc4
# contents of URL written to 494.nc4
# contents of URL written to 495.nc4
# contents of URL written to 496.nc4
# contents of URL written to 497.nc4
# contents of URL written to 498.nc4
# contents of URL written to 499.nc4
# contents of URL written to 500.nc4
# contents of URL written to 501.nc4
# contents of URL written to 502.nc4
# contents of URL written to 503.nc4
# contents of URL written to 504.nc4
# contents of URL written to 505.nc4
# contents of URL written to 506.nc4
# contents of URL written to 507.nc4
# contents of URL written to 508.nc4
# contents of URL written to 509.nc4
# contents of URL written to 510.nc4
# contents of URL written to 511.nc4
# contents of URL written to 512.nc4
# contents of URL written to 513.nc4
# contents of URL written to 514.nc4
# contents of URL written to 515.nc4
# contents of URL written to 516.nc4
# contents of URL written to 517.nc4
# contents of URL written to 518.nc4
# contents of URL written to 519.nc4
# contents of URL written to 520.nc4
# contents of URL written to 521.nc4
# contents of URL written to 522.nc4
# contents of URL written to 523.nc4
# contents of URL written to 524.nc4
# contents of URL written to 525.nc4
# contents of URL written to 526.nc4
# contents of URL written to 527.nc4
# contents of URL written to 528.nc4
# contents of URL written to 529.nc4
# contents of URL written to 530.nc4
# contents of URL written to 531.nc4
# contents of URL written to 532.nc4
# contents of URL written to 533.nc4
# contents of URL written to 534.nc4
# contents of URL written to 535.nc4
# contents of URL written to 536.nc4
# contents of URL written to 537.nc4
# contents of URL written to 538.nc4
# contents of URL written to 539.nc4
# contents of URL written to 540.nc4
# contents of URL written to 541.nc4
# contents of URL written to 542.nc4
# contents of URL written to 543.nc4
# contents of URL written to 544.nc4
# contents of URL written to 545.nc4
# contents of URL written to 546.nc4
# contents of URL written to 547.nc4
# contents of URL written to 548.nc4
# contents of URL written to 549.nc4
# contents of URL written to 550.nc4
# contents of URL written to 551.nc4
# contents of URL written to 552.nc4
# contents of URL written to 553.nc4
# contents of URL written to 554.nc4
# contents of URL written to 555.nc4
# contents of URL written to 556.nc4
# contents of URL written to 557.nc4
# contents of URL written to 558.nc4
# contents of URL written to 559.nc4
# contents of URL written to 560.nc4
# contents of URL written to 561.nc4
# contents of URL written to 562.nc4
# contents of URL written to 563.nc4
# contents of URL written to 564.nc4
# contents of URL written to 565.nc4
# contents of URL written to 566.nc4
# contents of URL written to 567.nc4
# contents of URL written to 568.nc4
# contents of URL written to 569.nc4
# contents of URL written to 570.nc4
# contents of URL written to 571.nc4
# contents of URL written to 572.nc4
# contents of URL written to 573.nc4
# contents of URL written to 574.nc4
# contents of URL written to 575.nc4
# contents of URL written to 576.nc4
# contents of URL written to 577.nc4
# contents of URL written to 578.nc4
# contents of URL written to 579.nc4
# contents of URL written to 580.nc4
# contents of URL written to 581.nc4
# contents of URL written to 582.nc4
# contents of URL written to 583.nc4
# contents of URL written to 584.nc4
# contents of URL written to 585.nc4
# contents of URL written to 586.nc4
# contents of URL written to 587.nc4
# contents of URL written to 588.nc4
# contents of URL written to 589.nc4
# contents of URL written to 590.nc4
# contents of URL written to 591.nc4
# contents of URL written to 592.nc4
# contents of URL written to 593.nc4
# contents of URL written to 594.nc4
# contents of URL written to 595.nc4
# contents of URL written to 596.nc4
# contents of URL written to 597.nc4
# contents of URL written to 598.nc4
# contents of URL written to 599.nc4
# contents of URL written to 600.nc4
# contents of URL written to 601.nc4
# contents of URL written to 602.nc4
# contents of URL written to 603.nc4
# contents of URL written to 604.nc4
# contents of URL written to 605.nc4
# contents of URL written to 606.nc4
# contents of URL written to 607.nc4
# contents of URL written to 608.nc4
# contents of URL written to 609.nc4
# contents of URL written to 610.nc4
# contents of URL written to 611.nc4
# contents of URL written to 612.nc4
# contents of URL written to 613.nc4
# contents of URL written to 614.nc4
# contents of URL written to 615.nc4
# contents of URL written to 616.nc4
# contents of URL written to 617.nc4
# contents of URL written to 618.nc4
# contents of URL written to 619.nc4
# contents of URL written to 620.nc4
# contents of URL written to 621.nc4
# contents of URL written to 622.nc4
# contents of URL written to 623.nc4
# contents of URL written to 624.nc4
# contents of URL written to 625.nc4
# contents of URL written to 626.nc4
# contents of URL written to 627.nc4
# contents of URL written to 628.nc4
# contents of URL written to 629.nc4
# contents of URL written to 630.nc4
# contents of URL written to 631.nc4
# contents of URL written to 632.nc4
# contents of URL written to 633.nc4
# contents of URL written to 634.nc4
# contents of URL written to 635.nc4
# contents of URL written to 636.nc4
# contents of URL written to 637.nc4
# contents of URL written to 638.nc4
# contents of URL written to 639.nc4
# contents of URL written to 640.nc4
# contents of URL written to 641.nc4
# contents of URL written to 642.nc4
# contents of URL written to 643.nc4
# contents of URL written to 644.nc4
# contents of URL written to 645.nc4
# contents of URL written to 646.nc4
# contents of URL written to 647.nc4
# contents of URL written to 648.nc4
# contents of URL written to 649.nc4
# contents of URL written to 650.nc4
# contents of URL written to 651.nc4
# contents of URL written to 652.nc4
# contents of URL written to 653.nc4
# contents of URL written to 654.nc4
# contents of URL written to 655.nc4
# contents of URL written to 656.nc4
# contents of URL written to 657.nc4
# contents of URL written to 658.nc4
# contents of URL written to 659.nc4
# contents of URL written to 660.nc4
# contents of URL written to 661.nc4
# contents of URL written to 662.nc4
# contents of URL written to 663.nc4
# contents of URL written to 664.nc4
# contents of URL written to 665.nc4
# contents of URL written to 666.nc4
# contents of URL written to 667.nc4
# contents of URL written to 668.nc4
# contents of URL written to 669.nc4
# contents of URL written to 670.nc4
# contents of URL written to 671.nc4
# contents of URL written to 672.nc4
# contents of URL written to 673.nc4
# contents of URL written to 674.nc4
# contents of URL written to 675.nc4
# contents of URL written to 676.nc4
# contents of URL written to 677.nc4
# contents of URL written to 678.nc4
# contents of URL written to 679.nc4
# contents of URL written to 680.nc4
# contents of URL written to 681.nc4
# contents of URL written to 682.nc4
# contents of URL written to 683.nc4
# contents of URL written to 684.nc4
# contents of URL written to 685.nc4
# contents of URL written to 686.nc4
# contents of URL written to 687.nc4
# contents of URL written to 688.nc4
# contents of URL written to 689.nc4
# contents of URL written to 690.nc4
# contents of URL written to 691.nc4
# contents of URL written to 692.nc4
# contents of URL written to 693.nc4
# contents of URL written to 694.nc4
# contents of URL written to 695.nc4
# contents of URL written to 696.nc4
# contents of URL written to 697.nc4
# contents of URL written to 698.nc4
# contents of URL written to 699.nc4
# contents of URL written to 700.nc4
# contents of URL written to 701.nc4
# contents of URL written to 702.nc4
# contents of URL written to 703.nc4
# contents of URL written to 704.nc4
# contents of URL written to 705.nc4
# contents of URL written to 706.nc4
# contents of URL written to 707.nc4
# contents of URL written to 708.nc4
# contents of URL written to 709.nc4
# contents of URL written to 710.nc4
# contents of URL written to 711.nc4
# contents of URL written to 712.nc4
# contents of URL written to 713.nc4
# contents of URL written to 714.nc4
# contents of URL written to 715.nc4
# contents of URL written to 716.nc4
# contents of URL written to 717.nc4
# contents of URL written to 718.nc4
# contents of URL written to 719.nc4
# contents of URL written to 720.nc4
# contents of URL written to 721.nc4
# contents of URL written to 722.nc4
# contents of URL written to 723.nc4
# contents of URL written to 724.nc4
# contents of URL written to 725.nc4
# contents of URL written to 726.nc4
# contents of URL written to 727.nc4
# contents of URL written to 728.nc4
# contents of URL written to 729.nc4
# contents of URL written to 730.nc4
# contents of URL written to 731.nc4
# contents of URL written to 732.nc4
# contents of URL written to 733.nc4
# contents of URL written to 734.nc4
# contents of URL written to 735.nc4
# contents of URL written to 736.nc4
# contents of URL written to 737.nc4
# contents of URL written to 738.nc4
# contents of URL written to 739.nc4
# contents of URL written to 740.nc4
# contents of URL written to 741.nc4
# contents of URL written to 742.nc4
# contents of URL written to 743.nc4
# contents of URL written to 744.nc4
# contents of URL written to 745.nc4
# contents of URL written to 746.nc4
# contents of URL written to 747.nc4
# contents of URL written to 748.nc4
# contents of URL written to 749.nc4
# contents of URL written to 750.nc4
# contents of URL written to 751.nc4
# contents of URL written to 752.nc4
# contents of URL written to 753.nc4
# contents of URL written to 754.nc4
# contents of URL written to 755.nc4
# contents of URL written to 756.nc4
# contents of URL written to 757.nc4
# contents of URL written to 758.nc4
# contents of URL written to 759.nc4
# contents of URL written to 760.nc4
# contents of URL written to 761.nc4
# contents of URL written to 762.nc4
# contents of URL written to 763.nc4
# contents of URL written to 764.nc4
# contents of URL written to 765.nc4
# contents of URL written to 766.nc4
# contents of URL written to 767.nc4
# contents of URL written to 768.nc4
# contents of URL written to 769.nc4
# contents of URL written to 770.nc4
# contents of URL written to 771.nc4
# contents of URL written to 772.nc4
# contents of URL written to 773.nc4
# contents of URL written to 774.nc4
# contents of URL written to 775.nc4
# contents of URL written to 776.nc4
# contents of URL written to 777.nc4
# contents of URL written to 778.nc4
# contents of URL written to 779.nc4
# contents of URL written to 780.nc4
# contents of URL written to 781.nc4
# contents of URL written to 782.nc4
# contents of URL written to 783.nc4
# contents of URL written to 784.nc4
# contents of URL written to 785.nc4
# contents of URL written to 786.nc4
# contents of URL written to 787.nc4
# contents of URL written to 788.nc4
# contents of URL written to 789.nc4
# contents of URL written to 790.nc4
# contents of URL written to 791.nc4
# contents of URL written to 792.nc4
# contents of URL written to 793.nc4
# contents of URL written to 794.nc4
# contents of URL written to 795.nc4
# contents of URL written to 796.nc4
# contents of URL written to 797.nc4
# contents of URL written to 798.nc4
# contents of URL written to 799.nc4
# contents of URL written to 800.nc4
# contents of URL written to 801.nc4
# contents of URL written to 802.nc4
# contents of URL written to 803.nc4
# contents of URL written to 804.nc4
# contents of URL written to 805.nc4
# contents of URL written to 806.nc4
# contents of URL written to 807.nc4
# contents of URL written to 808.nc4
# contents of URL written to 809.nc4
# contents of URL written to 810.nc4
# contents of URL written to 811.nc4
# contents of URL written to 812.nc4
# contents of URL written to 813.nc4
# contents of URL written to 814.nc4
# contents of URL written to 815.nc4
# contents of URL written to 816.nc4
# contents of URL written to 817.nc4
# contents of URL written to 818.nc4
# contents of URL written to 819.nc4
# contents of URL written to 820.nc4
# contents of URL written to 821.nc4
# contents of URL written to 822.nc4
# contents of URL written to 823.nc4
# contents of URL written to 824.nc4
# contents of URL written to 825.nc4
# contents of URL written to 826.nc4
# contents of URL written to 827.nc4
# contents of URL written to 828.nc4
# contents of URL written to 829.nc4
# contents of URL written to 830.nc4
# contents of URL written to 831.nc4
# contents of URL written to 832.nc4
# contents of URL written to 833.nc4
# contents of URL written to 834.nc4
# contents of URL written to 835.nc4
# contents of URL written to 836.nc4
# contents of URL written to 837.nc4
# contents of URL written to 838.nc4
# contents of URL written to 839.nc4
# contents of URL written to 840.nc4
# contents of URL written to 841.nc4
# contents of URL written to 842.nc4
# contents of URL written to 843.nc4
# contents of URL written to 844.nc4
# contents of URL written to 845.nc4
# contents of URL written to 846.nc4
# contents of URL written to 847.nc4
# contents of URL written to 848.nc4
# contents of URL written to 849.nc4
# contents of URL written to 850.nc4
# contents of URL written to 851.nc4
# contents of URL written to 852.nc4
# contents of URL written to 853.nc4
# contents of URL written to 854.nc4
# contents of URL written to 855.nc4
# contents of URL written to 856.nc4
# contents of URL written to 857.nc4
# contents of URL written to 858.nc4
# contents of URL written to 859.nc4
# contents of URL written to 860.nc4
# contents of URL written to 861.nc4
# contents of URL written to 862.nc4
# contents of URL written to 863.nc4
# contents of URL written to 864.nc4
# contents of URL written to 865.nc4
# contents of URL written to 866.nc4
# contents of URL written to 867.nc4
# contents of URL written to 868.nc4
# contents of URL written to 869.nc4
# contents of URL written to 870.nc4
# contents of URL written to 871.nc4
# contents of URL written to 872.nc4
# contents of URL written to 873.nc4
# contents of URL written to 874.nc4
# contents of URL written to 875.nc4
# contents of URL written to 876.nc4
# contents of URL written to 877.nc4
# contents of URL written to 878.nc4
# contents of URL written to 879.nc4
# contents of URL written to 880.nc4
# contents of URL written to 881.nc4
# contents of URL written to 882.nc4
# contents of URL written to 883.nc4
# contents of URL written to 884.nc4
# contents of URL written to 885.nc4
# contents of URL written to 886.nc4
# contents of URL written to 887.nc4
# contents of URL written to 888.nc4
# contents of URL written to 889.nc4
# contents of URL written to 890.nc4
# contents of URL written to 891.nc4
# contents of URL written to 892.nc4
# contents of URL written to 893.nc4
# contents of URL written to 894.nc4
# contents of URL written to 895.nc4
# contents of URL written to 896.nc4
# contents of URL written to 897.nc4
# contents of URL written to 898.nc4
# contents of URL written to 899.nc4
# contents of URL written to 900.nc4
# contents of URL written to 901.nc4
# contents of URL written to 902.nc4
# contents of URL written to 903.nc4
# contents of URL written to 904.nc4
# contents of URL written to 905.nc4
# contents of URL written to 906.nc4
# contents of URL written to 907.nc4
# contents of URL written to 908.nc4
# contents of URL written to 909.nc4
# contents of URL written to 910.nc4
# contents of URL written to 911.nc4
# contents of URL written to 912.nc4
# contents of URL written to 913.nc4
# contents of URL written to 914.nc4
# contents of URL written to 915.nc4
# contents of URL written to 916.nc4
# contents of URL written to 917.nc4
# contents of URL written to 918.nc4
# contents of URL written to 919.nc4
# contents of URL written to 920.nc4
# contents of URL written to 921.nc4
# contents of URL written to 922.nc4
# contents of URL written to 923.nc4
# contents of URL written to 924.nc4
# contents of URL written to 925.nc4
# contents of URL written to 926.nc4
# contents of URL written to 927.nc4
# contents of URL written to 928.nc4
# contents of URL written to 929.nc4
# contents of URL written to 930.nc4
# contents of URL written to 931.nc4
# contents of URL written to 932.nc4
# contents of URL written to 933.nc4
# contents of URL written to 934.nc4
# contents of URL written to 935.nc4
# contents of URL written to 936.nc4
# contents of URL written to 937.nc4
# contents of URL written to 938.nc4
# contents of URL written to 939.nc4
# contents of URL written to 940.nc4
# contents of URL written to 941.nc4
# contents of URL written to 942.nc4
# contents of URL written to 943.nc4
# contents of URL written to 944.nc4
# contents of URL written to 945.nc4
# contents of URL written to 946.nc4
# contents of URL written to 947.nc4
# contents of URL written to 948.nc4
# contents of URL written to 949.nc4
# contents of URL written to 950.nc4
# contents of URL written to 951.nc4
# contents of URL written to 952.nc4
# contents of URL written to 953.nc4
# contents of URL written to 954.nc4
# contents of URL written to 955.nc4
# contents of URL written to 956.nc4
# contents of URL written to 957.nc4
# contents of URL written to 958.nc4
# contents of URL written to 959.nc4
# contents of URL written to 960.nc4
# contents of URL written to 961.nc4
# contents of URL written to 962.nc4
# contents of URL written to 963.nc4
# contents of URL written to 964.nc4
# contents of URL written to 965.nc4
# contents of URL written to 966.nc4
# contents of URL written to 967.nc4
# contents of URL written to 968.nc4
# contents of URL written to 969.nc4
# contents of URL written to 970.nc4
# contents of URL written to 971.nc4
# contents of URL written to 972.nc4
# contents of URL written to 973.nc4
# contents of URL written to 974.nc4
# contents of URL written to 975.nc4
# contents of URL written to 976.nc4
# contents of URL written to 977.nc4
# contents of URL written to 978.nc4
# contents of URL written to 979.nc4
# contents of URL written to 980.nc4
# contents of URL written to 981.nc4
# contents of URL written to 982.nc4
# contents of URL written to 983.nc4
# contents of URL written to 984.nc4
# contents of URL written to 985.nc4
# contents of URL written to 986.nc4
# contents of URL written to 987.nc4
# contents of URL written to 988.nc4
# contents of URL written to 989.nc4
# contents of URL written to 990.nc4
# contents of URL written to 991.nc4
# contents of URL written to 992.nc4
# contents of URL written to 993.nc4
# contents of URL written to 994.nc4
# contents of URL written to 995.nc4
# contents of URL written to 996.nc4
# contents of URL written to 997.nc4
# contents of URL written to 998.nc4
# contents of URL written to 999.nc4
# contents of URL written to 1000.nc4
# contents of URL written to 1001.nc4
# contents of URL written to 1002.nc4
# contents of URL written to 1003.nc4
# contents of URL written to 1004.nc4
# contents of URL written to 1005.nc4
# contents of URL written to 1006.nc4
# contents of URL written to 1007.nc4
# contents of URL written to 1008.nc4
# contents of URL written to 1009.nc4
# contents of URL written to 1010.nc4
# contents of URL written to 1011.nc4
# contents of URL written to 1012.nc4
# contents of URL written to 1013.nc4
# contents of URL written to 1014.nc4
# contents of URL written to 1015.nc4
# contents of URL written to 1016.nc4
# contents of URL written to 1017.nc4
# contents of URL written to 1018.nc4
# contents of URL written to 1019.nc4
# contents of URL written to 1020.nc4
# contents of URL written to 1021.nc4
# contents of URL written to 1022.nc4
# contents of URL written to 1023.nc4
# contents of URL written to 1024.nc4
# contents of URL written to 1025.nc4
# contents of URL written to 1026.nc4
# contents of URL written to 1027.nc4
# contents of URL written to 1028.nc4
# contents of URL written to 1029.nc4
# contents of URL written to 1030.nc4
# contents of URL written to 1031.nc4
# contents of URL written to 1032.nc4
# contents of URL written to 1033.nc4
# contents of URL written to 1034.nc4
# contents of URL written to 1035.nc4
# contents of URL written to 1036.nc4
# contents of URL written to 1037.nc4
# contents of URL written to 1038.nc4
# contents of URL written to 1039.nc4
# contents of URL written to 1040.nc4
# contents of URL written to 1041.nc4
# contents of URL written to 1042.nc4
# contents of URL written to 1043.nc4
# contents of URL written to 1044.nc4
# contents of URL written to 1045.nc4
# contents of URL written to 1046.nc4
# contents of URL written to 1047.nc4
# contents of URL written to 1048.nc4
# contents of URL written to 1049.nc4
# contents of URL written to 1050.nc4
# contents of URL written to 1051.nc4
# contents of URL written to 1052.nc4
# contents of URL written to 1053.nc4
# contents of URL written to 1054.nc4
# contents of URL written to 1055.nc4
# contents of URL written to 1056.nc4
# contents of URL written to 1057.nc4
# contents of URL written to 1058.nc4
# contents of URL written to 1059.nc4
# contents of URL written to 1060.nc4
# contents of URL written to 1061.nc4
# contents of URL written to 1062.nc4
# contents of URL written to 1063.nc4
# contents of URL written to 1064.nc4
# contents of URL written to 1065.nc4
# contents of URL written to 1066.nc4
# contents of URL written to 1067.nc4
# contents of URL written to 1068.nc4
# contents of URL written to 1069.nc4
# contents of URL written to 1070.nc4
# contents of URL written to 1071.nc4
# contents of URL written to 1072.nc4
# contents of URL written to 1073.nc4
# contents of URL written to 1074.nc4
# contents of URL written to 1075.nc4
# contents of URL written to 1076.nc4
# contents of URL written to 1077.nc4
# contents of URL written to 1078.nc4
# contents of URL written to 1079.nc4
# contents of URL written to 1080.nc4
# contents of URL written to 1081.nc4
# contents of URL written to 1082.nc4
# contents of URL written to 1083.nc4
# contents of URL written to 1084.nc4
# contents of URL written to 1085.nc4
# contents of URL written to 1086.nc4
# contents of URL written to 1087.nc4
# contents of URL written to 1088.nc4
# contents of URL written to 1089.nc4
# contents of URL written to 1090.nc4
# contents of URL written to 1091.nc4
# contents of URL written to 1092.nc4
# contents of URL written to 1093.nc4
# contents of URL written to 1094.nc4
# contents of URL written to 1095.nc4
# contents of URL written to 1096.nc4
# contents of URL written to 1097.nc4
# contents of URL written to 1098.nc4
# contents of URL written to 1099.nc4
# contents of URL written to 1100.nc4
# contents of URL written to 1101.nc4
# contents of URL written to 1102.nc4
# contents of URL written to 1103.nc4
# contents of URL written to 1104.nc4
# contents of URL written to 1105.nc4
# contents of URL written to 1106.nc4
# contents of URL written to 1107.nc4
# contents of URL written to 1108.nc4
# contents of URL written to 1109.nc4
# contents of URL written to 1110.nc4
# contents of URL written to 1111.nc4
# contents of URL written to 1112.nc4
# contents of URL written to 1113.nc4
# contents of URL written to 1114.nc4
# contents of URL written to 1115.nc4
# contents of URL written to 1116.nc4
# contents of URL written to 1117.nc4
# contents of URL written to 1118.nc4
# contents of URL written to 1119.nc4
# contents of URL written to 1120.nc4
# contents of URL written to 1121.nc4
# contents of URL written to 1122.nc4
# contents of URL written to 1123.nc4
# contents of URL written to 1124.nc4
# contents of URL written to 1125.nc4
# contents of URL written to 1126.nc4
# contents of URL written to 1127.nc4
# contents of URL written to 1128.nc4
# contents of URL written to 1129.nc4
# contents of URL written to 1130.nc4
# contents of URL written to 1131.nc4
# contents of URL written to 1132.nc4
# contents of URL written to 1133.nc4
# contents of URL written to 1134.nc4
# contents of URL written to 1135.nc4
# contents of URL written to 1136.nc4
# contents of URL written to 1137.nc4
# contents of URL written to 1138.nc4
# contents of URL written to 1139.nc4
# contents of URL written to 1140.nc4
# contents of URL written to 1141.nc4
# contents of URL written to 1142.nc4
# contents of URL written to 1143.nc4
# contents of URL written to 1144.nc4
# contents of URL written to 1145.nc4
# contents of URL written to 1146.nc4
# contents of URL written to 1147.nc4
# contents of URL written to 1148.nc4
# contents of URL written to 1149.nc4
# contents of URL written to 1150.nc4
# contents of URL written to 1151.nc4
# contents of URL written to 1152.nc4
# contents of URL written to 1153.nc4
# contents of URL written to 1154.nc4
# contents of URL written to 1155.nc4
# contents of URL written to 1156.nc4
# contents of URL written to 1157.nc4
# contents of URL written to 1158.nc4
# contents of URL written to 1159.nc4
# contents of URL written to 1160.nc4
# contents of URL written to 1161.nc4
# contents of URL written to 1162.nc4
# contents of URL written to 1163.nc4
# contents of URL written to 1164.nc4
# contents of URL written to 1165.nc4
# contents of URL written to 1166.nc4
# contents of URL written to 1167.nc4
# contents of URL written to 1168.nc4
# contents of URL written to 1169.nc4
# contents of URL written to 1170.nc4
# contents of URL written to 1171.nc4
# contents of URL written to 1172.nc4
# contents of URL written to 1173.nc4
# contents of URL written to 1174.nc4
# contents of URL written to 1175.nc4
# contents of URL written to 1176.nc4
# contents of URL written to 1177.nc4
# contents of URL written to 1178.nc4
# contents of URL written to 1179.nc4
# contents of URL written to 1180.nc4
# contents of URL written to 1181.nc4
# contents of URL written to 1182.nc4
# contents of URL written to 1183.nc4
# contents of URL written to 1184.nc4
# contents of URL written to 1185.nc4
# contents of URL written to 1186.nc4
# contents of URL written to 1187.nc4
# contents of URL written to 1188.nc4
# contents of URL written to 1189.nc4
# contents of URL written to 1190.nc4
# contents of URL written to 1191.nc4
# contents of URL written to 1192.nc4
# contents of URL written to 1193.nc4
# contents of URL written to 1194.nc4
# contents of URL written to 1195.nc4
# contents of URL written to 1196.nc4
# contents of URL written to 1197.nc4
# contents of URL written to 1198.nc4
# contents of URL written to 1199.nc4
# contents of URL written to 1200.nc4
# contents of URL written to 1201.nc4
# contents of URL written to 1202.nc4
# contents of URL written to 1203.nc4
# contents of URL written to 1204.nc4
# contents of URL written to 1205.nc4
# contents of URL written to 1206.nc4
# contents of URL written to 1207.nc4
# contents of URL written to 1208.nc4
# contents of URL written to 1209.nc4
# contents of URL written to 1210.nc4
# contents of URL written to 1211.nc4
# contents of URL written to 1212.nc4
# contents of URL written to 1213.nc4
# contents of URL written to 1214.nc4
# contents of URL written to 1215.nc4
# contents of URL written to 1216.nc4
# contents of URL written to 1217.nc4
# contents of URL written to 1218.nc4
# contents of URL written to 1219.nc4
# contents of URL written to 1220.nc4
# contents of URL written to 1221.nc4
# contents of URL written to 1222.nc4
# contents of URL written to 1223.nc4
# contents of URL written to 1224.nc4
# contents of URL written to 1225.nc4
# contents of URL written to 1226.nc4
# contents of URL written to 1227.nc4
# contents of URL written to 1228.nc4
# contents of URL written to 1229.nc4
# contents of URL written to 1230.nc4
# contents of URL written to 1231.nc4
# contents of URL written to 1232.nc4
# contents of URL written to 1233.nc4
# contents of URL written to 1234.nc4
# contents of URL written to 1235.nc4
# contents of URL written to 1236.nc4
# contents of URL written to 1237.nc4
# contents of URL written to 1238.nc4
# contents of URL written to 1239.nc4
# contents of URL written to 1240.nc4
# contents of URL written to 1241.nc4
# contents of URL written to 1242.nc4
# contents of URL written to 1243.nc4
# contents of URL written to 1244.nc4
# contents of URL written to 1245.nc4
# contents of URL written to 1246.nc4
# contents of URL written to 1247.nc4
# contents of URL written to 1248.nc4
# contents of URL written to 1249.nc4
# contents of URL written to 1250.nc4
# contents of URL written to 1251.nc4
# contents of URL written to 1252.nc4
# contents of URL written to 1253.nc4
# contents of URL written to 1254.nc4
# contents of URL written to 1255.nc4
# contents of URL written to 1256.nc4
# contents of URL written to 1257.nc4
# contents of URL written to 1258.nc4
# contents of URL written to 1259.nc4
# contents of URL written to 1260.nc4
# contents of URL written to 1261.nc4
# contents of URL written to 1262.nc4
# contents of URL written to 1263.nc4
# contents of URL written to 1264.nc4
# contents of URL written to 1265.nc4
# contents of URL written to 1266.nc4
# contents of URL written to 1267.nc4
# contents of URL written to 1268.nc4
# contents of URL written to 1269.nc4
# contents of URL written to 1270.nc4
# contents of URL written to 1271.nc4
# contents of URL written to 1272.nc4
# contents of URL written to 1273.nc4
# contents of URL written to 1274.nc4
# contents of URL written to 1275.nc4
# contents of URL written to 1276.nc4
# contents of URL written to 1277.nc4
# contents of URL written to 1278.nc4
# contents of URL written to 1279.nc4
# contents of URL written to 1280.nc4
# contents of URL written to 1281.nc4
# contents of URL written to 1282.nc4
# contents of URL written to 1283.nc4
# contents of URL written to 1284.nc4
# contents of URL written to 1285.nc4
# contents of URL written to 1286.nc4
# contents of URL written to 1287.nc4
# contents of URL written to 1288.nc4
# contents of URL written to 1289.nc4
# contents of URL written to 1290.nc4
# contents of URL written to 1291.nc4
# contents of URL written to 1292.nc4
# contents of URL written to 1293.nc4
# contents of URL written to 1294.nc4
# contents of URL written to 1295.nc4
# contents of URL written to 1296.nc4
# contents of URL written to 1297.nc4
# contents of URL written to 1298.nc4
# contents of URL written to 1299.nc4
# contents of URL written to 1300.nc4
# contents of URL written to 1301.nc4
# contents of URL written to 1302.nc4
# contents of URL written to 1303.nc4
# contents of URL written to 1304.nc4
# contents of URL written to 1305.nc4
# contents of URL written to 1306.nc4
# contents of URL written to 1307.nc4
# contents of URL written to 1308.nc4
# contents of URL written to 1309.nc4
# contents of URL written to 1310.nc4
# contents of URL written to 1311.nc4
# contents of URL written to 1312.nc4
# contents of URL written to 1313.nc4
# contents of URL written to 1314.nc4
# contents of URL written to 1315.nc4
# contents of URL written to 1316.nc4
# contents of URL written to 1317.nc4
# contents of URL written to 1318.nc4
# contents of URL written to 1319.nc4
# contents of URL written to 1320.nc4
# contents of URL written to 1321.nc4
# contents of URL written to 1322.nc4
# contents of URL written to 1323.nc4
# contents of URL written to 1324.nc4
# contents of URL written to 1325.nc4
# contents of URL written to 1326.nc4
# contents of URL written to 1327.nc4
# contents of URL written to 1328.nc4
# contents of URL written to 1329.nc4
# contents of URL written to 1330.nc4
# contents of URL written to 1331.nc4
# contents of URL written to 1332.nc4
# contents of URL written to 1333.nc4
# contents of URL written to 1334.nc4
# contents of URL written to 1335.nc4
# contents of URL written to 1336.nc4
# contents of URL written to 1337.nc4
# contents of URL written to 1338.nc4
# contents of URL written to 1339.nc4
# contents of URL written to 1340.nc4
# contents of URL written to 1341.nc4
# contents of URL written to 1342.nc4
# contents of URL written to 1343.nc4
# contents of URL written to 1344.nc4
# contents of URL written to 1345.nc4
# contents of URL written to 1346.nc4
# contents of URL written to 1347.nc4
# contents of URL written to 1348.nc4
# contents of URL written to 1349.nc4
# contents of URL written to 1350.nc4
# contents of URL written to 1351.nc4
# contents of URL written to 1352.nc4
# contents of URL written to 1353.nc4
# contents of URL written to 1354.nc4
# contents of URL written to 1355.nc4
# contents of URL written to 1356.nc4
# contents of URL written to 1357.nc4
# contents of URL written to 1358.nc4
# contents of URL written to 1359.nc4
# contents of URL written to 1360.nc4
# contents of URL written to 1361.nc4
# contents of URL written to 1362.nc4
# contents of URL written to 1363.nc4
# contents of URL written to 1364.nc4
# ...
# contents of URL written to 6466.nc4
# contents of URL written to 6467.nc4
# contents of URL written to 6468.nc4
# contents of URL written to 6469.nc4
# contents of URL written to 6470.nc4
# contents of URL written to 6471.nc4
# contents of URL written to 6472.nc4
# contents of URL written to 6473.nc4
# contents of URL written to 6474.nc4
# contents of URL written to 6475.nc4
# contents of URL written to 6476.nc4
# contents of URL written to 6477.nc4
# contents of URL written to 6478.nc4
# contents of URL written to 6479.nc4
# contents of URL written to 6480.nc4
# contents of URL written to 6481.nc4
# contents of URL written to 6482.nc4
# contents of URL written to 6483.nc4
# contents of URL written to 6484.nc4
# contents of URL written to 6485.nc4
# contents of URL written to 6486.nc4
# contents of URL written to 6487.nc4
# contents of URL written to 6488.nc4
# contents of URL written to 6489.nc4
# contents of URL written to 6490.nc4
# contents of URL written to 6491.nc4
# contents of URL written to 6492.nc4
# contents of URL written to 6493.nc4
# contents of URL written to 6494.nc4
# contents of URL written to 6495.nc4
# contents of URL written to 6496.nc4
# contents of URL written to 6497.nc4
# contents of URL written to 6498.nc4
# contents of URL written to 6499.nc4
# contents of URL written to 6500.nc4
# contents of URL written to 6501.nc4
# contents of URL written to 6502.nc4
# contents of URL written to 6503.nc4
# contents of URL written to 6504.nc4
# contents of URL written to 6505.nc4
# contents of URL written to 6506.nc4
# contents of URL written to 6507.nc4
# contents of URL written to 6508.nc4
# contents of URL written to 6509.nc4
# contents of URL written to 6510.nc4
# contents of URL written to 6511.nc4
# contents of URL written to 6512.nc4
# contents of URL written to 6513.nc4
# contents of URL written to 6514.nc4
# contents of URL written to 6515.nc4
# contents of URL written to 6516.nc4
# contents of URL written to 6517.nc4
# contents of URL written to 6518.nc4
# contents of URL written to 6519.nc4
# contents of URL written to 6520.nc4
# contents of URL written to 6521.nc4
# contents of URL written to 6522.nc4
# contents of URL written to 6523.nc4
# contents of URL written to 6524.nc4
# contents of URL written to 6525.nc4
# contents of URL written to 6526.nc4
# contents of URL written to 6527.nc4
# contents of URL written to 6528.nc4
# contents of URL written to 6529.nc4
# contents of URL written to 6530.nc4
# contents of URL written to 6531.nc4
# contents of URL written to 6532.nc4
# contents of URL written to 6533.nc4
# contents of URL written to 6534.nc4
# contents of URL written to 6535.nc4
# contents of URL written to 6536.nc4
# contents of URL written to 6537.nc4
# contents of URL written to 6538.nc4
# contents of URL written to 6539.nc4
# contents of URL written to 6540.nc4
# contents of URL written to 6541.nc4
# contents of URL written to 6542.nc4
# contents of URL written to 6543.nc4
# contents of URL written to 6544.nc4
# contents of URL written to 6545.nc4
# contents of URL written to 6546.nc4
# contents of URL written to 6547.nc4
# contents of URL written to 6548.nc4
# contents of URL written to 6549.nc4
# contents of URL written to 6550.nc4
# contents of URL written to 6551.nc4
# contents of URL written to 6552.nc4
# contents of URL written to 6553.nc4
# contents of URL written to 6554.nc4
# contents of URL written to 6555.nc4
# contents of URL written to 6556.nc4
# contents of URL written to 6557.nc4
# contents of URL written to 6558.nc4
# contents of URL written to 6559.nc4
# contents of URL written to 6560.nc4
# contents of URL written to 6561.nc4
# contents of URL written to 6562.nc4
# contents of URL written to 6563.nc4
# contents of URL written to 6564.nc4
# contents of URL written to 6565.nc4
# contents of URL written to 6566.nc4
# contents of URL written to 6567.nc4
# contents of URL written to 6568.nc4
# contents of URL written to 6569.nc4
# contents of URL written to 6570.nc4
# contents of URL written to 6571.nc4
# contents of URL written to 6572.nc4
# contents of URL written to 6573.nc4
# contents of URL written to 6574.nc4
# contents of URL written to 6575.nc4
# contents of URL written to 6576.nc4
# contents of URL written to 6577.nc4
# contents of URL written to 6578.nc4
# contents of URL written to 6579.nc4
# contents of URL written to 6580.nc4
# contents of URL written to 6581.nc4
# contents of URL written to 6582.nc4
# contents of URL written to 6583.nc4
# contents of URL written to 6584.nc4
# contents of URL written to 6585.nc4
# contents of URL written to 6586.nc4
# contents of URL written to 6587.nc4
# contents of URL written to 6588.nc4
# contents of URL written to 6589.nc4
# contents of URL written to 6590.nc4
# contents of URL written to 6591.nc4
# contents of URL written to 6592.nc4
# contents of URL written to 6593.nc4
# contents of URL written to 6594.nc4
# contents of URL written to 6595.nc4
# contents of URL written to 6596.nc4
# contents of URL written to 6597.nc4
# contents of URL written to 6598.nc4
# contents of URL written to 6599.nc4
# contents of URL written to 6600.nc4
# contents of URL written to 6601.nc4
# contents of URL written to 6602.nc4
# contents of URL written to 6603.nc4
# contents of URL written to 6604.nc4
# contents of URL written to 6605.nc4
# contents of URL written to 6606.nc4
# contents of URL written to 6607.nc4
# contents of URL written to 6608.nc4
# contents of URL written to 6609.nc4
# contents of URL written to 6610.nc4
# contents of URL written to 6611.nc4
# contents of URL written to 6612.nc4
# contents of URL written to 6613.nc4
# contents of URL written to 6614.nc4
# contents of URL written to 6615.nc4
# contents of URL written to 6616.nc4
# contents of URL written to 6617.nc4
# contents of URL written to 6618.nc4
# contents of URL written to 6619.nc4
# contents of URL written to 6620.nc4
# contents of URL written to 6621.nc4
# contents of URL written to 6622.nc4
# contents of URL written to 6623.nc4
# contents of URL written to 6624.nc4
# contents of URL written to 6625.nc4
# contents of URL written to 6626.nc4
# contents of URL written to 6627.nc4
# contents of URL written to 6628.nc4
# contents of URL written to 6629.nc4
# contents of URL written to 6630.nc4
# contents of URL written to 6631.nc4
# contents of URL written to 6632.nc4
# contents of URL written to 6633.nc4
# contents of URL written to 6634.nc4
# contents of URL written to 6635.nc4
# contents of URL written to 6636.nc4
# contents of URL written to 6637.nc4
# contents of URL written to 6638.nc4
# contents of URL written to 6639.nc4
# contents of URL written to 6640.nc4
# contents of URL written to 6641.nc4
# contents of URL written to 6642.nc4
# contents of URL written to 6643.nc4
# contents of URL written to 6644.nc4
# contents of URL written to 6645.nc4
# contents of URL written to 6646.nc4
# contents of URL written to 6647.nc4
# contents of URL written to 6648.nc4
# contents of URL written to 6649.nc4
# contents of URL written to 6650.nc4
# contents of URL written to 6651.nc4
# contents of URL written to 6652.nc4
# contents of URL written to 6653.nc4
# contents of URL written to 6654.nc4
# contents of URL written to 6655.nc4
# contents of URL written to 6656.nc4
# contents of URL written to 6657.nc4
# contents of URL written to 6658.nc4
# contents of URL written to 6659.nc4
# contents of URL written to 6660.nc4
# contents of URL written to 6661.nc4
# contents of URL written to 6662.nc4
# contents of URL written to 6663.nc4
# contents of URL written to 6664.nc4
# contents of URL written to 6665.nc4
# contents of URL written to 6666.nc4
# contents of URL written to 6667.nc4
# contents of URL written to 6668.nc4
# contents of URL written to 6669.nc4
# contents of URL written to 6670.nc4
# contents of URL written to 6671.nc4
# contents of URL written to 6672.nc4
# contents of URL written to 6673.nc4
# contents of URL written to 6674.nc4
# contents of URL written to 6675.nc4
# contents of URL written to 6676.nc4
# contents of URL written to 6677.nc4
# contents of URL written to 6678.nc4
# contents of URL written to 6679.nc4
# contents of URL written to 6680.nc4
# contents of URL written to 6681.nc4
# contents of URL written to 6682.nc4
# contents of URL written to 6683.nc4
# contents of URL written to 6684.nc4
# contents of URL written to 6685.nc4
# contents of URL written to 6686.nc4
# contents of URL written to 6687.nc4
# contents of URL written to 6688.nc4
# contents of URL written to 6689.nc4
# contents of URL written to 6690.nc4
# contents of URL written to 6691.nc4
# contents of URL written to 6692.nc4
# contents of URL written to 6693.nc4
# contents of URL written to 6694.nc4
# contents of URL written to 6695.nc4
# contents of URL written to 6696.nc4
# contents of URL written to 6697.nc4
# contents of URL written to 6698.nc4
# contents of URL written to 6699.nc4
# contents of URL written to 6700.nc4
# contents of URL written to 6701.nc4
# contents of URL written to 6702.nc4
# contents of URL written to 6703.nc4
# contents of URL written to 6704.nc4
# contents of URL written to 6705.nc4
# contents of URL written to 6706.nc4
# contents of URL written to 6707.nc4
# contents of URL written to 6708.nc4
# contents of URL written to 6709.nc4
# contents of URL written to 6710.nc4
# contents of URL written to 6711.nc4
# contents of URL written to 6712.nc4
# contents of URL written to 6713.nc4
# contents of URL written to 6714.nc4
# contents of URL written to 6715.nc4
# contents of URL written to 6716.nc4
# contents of URL written to 6717.nc4
# contents of URL written to 6718.nc4
# contents of URL written to 6719.nc4
# contents of URL written to 6720.nc4
# contents of URL written to 6721.nc4
# contents of URL written to 6722.nc4
# contents of URL written to 6723.nc4
# contents of URL written to 6724.nc4
# contents of URL written to 6725.nc4
# contents of URL written to 6726.nc4
# contents of URL written to 6727.nc4
# contents of URL written to 6728.nc4
# contents of URL written to 6729.nc4
# contents of URL written to 6730.nc4
# contents of URL written to 6731.nc4
# contents of URL written to 6732.nc4
# contents of URL written to 6733.nc4
# contents of URL written to 6734.nc4
# contents of URL written to 6735.nc4
# contents of URL written to 6736.nc4
# contents of URL written to 6737.nc4
# contents of URL written to 6738.nc4
# contents of URL written to 6739.nc4
# contents of URL written to 6740.nc4
# contents of URL written to 6741.nc4
# contents of URL written to 6742.nc4
# contents of URL written to 6743.nc4
# contents of URL written to 6744.nc4
# contents of URL written to 6745.nc4
# contents of URL written to 6746.nc4
# contents of URL written to 6747.nc4
# contents of URL written to 6748.nc4
# contents of URL written to 6749.nc4
# contents of URL written to 6750.nc4
# contents of URL written to 6751.nc4
# contents of URL written to 6752.nc4
# contents of URL written to 6753.nc4
# contents of URL written to 6754.nc4
# contents of URL written to 6755.nc4
# contents of URL written to 6756.nc4
# contents of URL written to 6757.nc4
# contents of URL written to 6758.nc4
# contents of URL written to 6759.nc4
# contents of URL written to 6760.nc4
# contents of URL written to 6761.nc4
# contents of URL written to 6762.nc4
# contents of URL written to 6763.nc4
# contents of URL written to 6764.nc4
# contents of URL written to 6765.nc4
# contents of URL written to 6766.nc4
# contents of URL written to 6767.nc4
# contents of URL written to 6768.nc4
# contents of URL written to 6769.nc4
# contents of URL written to 6770.nc4
# contents of URL written to 6771.nc4
# contents of URL written to 6772.nc4
# contents of URL written to 6773.nc4
# contents of URL written to 6774.nc4
# contents of URL written to 6775.nc4
# contents of URL written to 6776.nc4
# contents of URL written to 6777.nc4
# contents of URL written to 6778.nc4
# contents of URL written to 6779.nc4
# contents of URL written to 6780.nc4
# contents of URL written to 6781.nc4
# contents of URL written to 6782.nc4
# contents of URL written to 6783.nc4
# contents of URL written to 6784.nc4
# contents of URL written to 6785.nc4
# contents of URL written to 6786.nc4
# contents of URL written to 6787.nc4
# contents of URL written to 6788.nc4
# contents of URL written to 6789.nc4
# contents of URL written to 6790.nc4
# contents of URL written to 6791.nc4
# contents of URL written to 6792.nc4
# contents of URL written to 6793.nc4
# contents of URL written to 6794.nc4
# contents of URL written to 6795.nc4
# contents of URL written to 6796.nc4
# contents of URL written to 6797.nc4
# contents of URL written to 6798.nc4
# contents of URL written to 6799.nc4
# contents of URL written to 6800.nc4
# contents of URL written to 6801.nc4
# contents of URL written to 6802.nc4
# contents of URL written to 6803.nc4
# contents of URL written to 6804.nc4
# contents of URL written to 6805.nc4
# contents of URL written to 6806.nc4
# contents of URL written to 6807.nc4
# contents of URL written to 6808.nc4
# contents of URL written to 6809.nc4
# contents of URL written to 6810.nc4
# contents of URL written to 6811.nc4
# contents of URL written to 6812.nc4
# contents of URL written to 6813.nc4
# contents of URL written to 6814.nc4
# contents of URL written to 6815.nc4
# contents of URL written to 6816.nc4
# contents of URL written to 6817.nc4
# contents of URL written to 6818.nc4
# contents of URL written to 6819.nc4
# contents of URL written to 6820.nc4
# contents of URL written to 6821.nc4
# contents of URL written to 6822.nc4
# contents of URL written to 6823.nc4
# contents of URL written to 6824.nc4
# contents of URL written to 6825.nc4
# contents of URL written to 6826.nc4
# contents of URL written to 6827.nc4
# contents of URL written to 6828.nc4
# contents of URL written to 6829.nc4
# contents of URL written to 6830.nc4
# contents of URL written to 6831.nc4
# contents of URL written to 6832.nc4
# contents of URL written to 6833.nc4
# contents of URL written to 6834.nc4
# contents of URL written to 6835.nc4
# contents of URL written to 6836.nc4
# contents of URL written to 6837.nc4
# contents of URL written to 6838.nc4
# contents of URL written to 6839.nc4
# contents of URL written to 6840.nc4
# contents of URL written to 6841.nc4
# contents of URL written to 6842.nc4
# contents of URL written to 6843.nc4
# contents of URL written to 6844.nc4
# contents of URL written to 6845.nc4
# contents of URL written to 6846.nc4
# contents of URL written to 6847.nc4
# contents of URL written to 6848.nc4
# contents of URL written to 6849.nc4
# contents of URL written to 6850.nc4
# contents of URL written to 6851.nc4
# contents of URL written to 6852.nc4
# contents of URL written to 6853.nc4
# contents of URL written to 6854.nc4
# contents of URL written to 6855.nc4
# contents of URL written to 6856.nc4
# contents of URL written to 6857.nc4
# contents of URL written to 6858.nc4
# contents of URL written to 6859.nc4
# contents of URL written to 6860.nc4
# contents of URL written to 6861.nc4
# contents of URL written to 6862.nc4
# contents of URL written to 6863.nc4
# contents of URL written to 6864.nc4
# contents of URL written to 6865.nc4
# contents of URL written to 6866.nc4
# contents of URL written to 6867.nc4
# contents of URL written to 6868.nc4
# contents of URL written to 6869.nc4
# contents of URL written to 6870.nc4
# contents of URL written to 6871.nc4
# contents of URL written to 6872.nc4
# contents of URL written to 6873.nc4
# contents of URL written to 6874.nc4
# contents of URL written to 6875.nc4
# contents of URL written to 6876.nc4
# contents of URL written to 6877.nc4
# contents of URL written to 6878.nc4
# contents of URL written to 6879.nc4
# contents of URL written to 6880.nc4
# contents of URL written to 6881.nc4
# contents of URL written to 6882.nc4
# contents of URL written to 6883.nc4
# contents of URL written to 6884.nc4
# contents of URL written to 6885.nc4
# contents of URL written to 6886.nc4
# contents of URL written to 6887.nc4
# contents of URL written to 6888.nc4
# contents of URL written to 6889.nc4
# contents of URL written to 6890.nc4
# contents of URL written to 6891.nc4
# contents of URL written to 6892.nc4
# contents of URL written to 6893.nc4
# contents of URL written to 6894.nc4
# contents of URL written to 6895.nc4
# contents of URL written to 6896.nc4
# contents of URL written to 6897.nc4
# contents of URL written to 6898.nc4
# contents of URL written to 6899.nc4
# contents of URL written to 6900.nc4
# contents of URL written to 6901.nc4
# contents of URL written to 6902.nc4
# contents of URL written to 6903.nc4
# contents of URL written to 6904.nc4
# contents of URL written to 6905.nc4
# contents of URL written to 6906.nc4
# contents of URL written to 6907.nc4
# contents of URL written to 6908.nc4
# contents of URL written to 6909.nc4
